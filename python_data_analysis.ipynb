# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\LENOVO\Downloads\Python_Diwali_Sales_Analysis-main\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv', encoding ='unicode_escape')

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
df.drop(['Status','unnamed1'], axis=1 , inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# to drop the null values from the dataframe
df.dropna(inplace=True)

# %%
# just to make sure that null values are deleted so the rows count will shown deducted..
df.shape
# Out:
# (11239, 13)

# %%
# to find out the null values in the dataframe
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
# intialize list of list
data_set = [['rameez',7],['ahmed',34],['arslan',31]]
#create the pandas dataframe using the list dataframe
df_test = pd.DataFrame(data_set, columns=['name','age'])

# %%
# to see the dataset again
df_test.head()
# Out:
#      name  age
# 0  rameez    7
# 1   ahmed   34
# 2  arslan   31

# %%
df_test
# Out:
#      name  age
# 0  rameez    7
# 1   ahmed   34
# 2  arslan   31

# %%
#change the data type
df['Amount'] = df['Amount'].astype('int')

# %%
# to check the data type of the Amount Column
df['Amount'].dtype
# Out:
# dtype('int64')

# %%
# to check all th ecolumns in the dataFrame
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# rename the column
df.rename(columns = {'Age':'umar'})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  umar  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35    28               0
# 1      1000732       Kartik  P00110942      F     26-35    35               1
# 2      1001990        Bindu  P00118542      F     26-35    35               1
# 3      1001425       Sudevi  P00237842      M      0-17    16               0
# 4      1000588         Joni  P00057942      M     26-35    28               1
# ...        ...          ...        ...    ...       ...   ...             ...
# 11246  1000695      Manning  P00296942      M     18-25    19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35    33               0
# 11248  1001209        Oshin  P00201342      F     36-45    40               0
# 11249  1004023       Noonan  P00059442      M     36-45    37               0
# 11250  1002744      Brumley  P00281742      F     18-25    19               0
#
# ...

# %%
# use describe() for specifi columns
df[['Amount','Orders']].describe()
# Out:
#              Amount        Orders
# count  11239.000000  11239.000000
# mean    9453.610553      2.489634
# std     5222.355168      1.114967
# min      188.000000      1.000000
# 25%     5443.000000      2.000000
# 50%     8109.000000      2.000000
# 75%    12675.000000      3.000000
# max    23952.000000      4.000000

# %% [markdown]
# # _Explorartory Data Analysis_

# %% [markdown]
# ## Gender

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax =sns.countplot(x='Gender',data=df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %%
sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.barplot(x='Gender', y='Amount', data = sales_gen )
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# most of the buyers  are  female, and even female have the more purchasing power...

# %% [markdown]
# ## age

# %%
sales_age = df.groupby(['Age Group'], as_index = False)['Amount'].sum().sort_values(by ='Amount', ascending = False )
sns.barplot(x ='Age Group', y='Amount', data = sales_age, palette='dark')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17260\1936790641.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x ='Age Group', y='Amount', data = sales_age, palette='dark')
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# the age group of 26_35 has the maximum spending as buyers..

# %%
ax = sns.countplot(data = df, x= 'Age Group', hue = 'Gender')
for bars in ax.containers: 
    ax.bar_label(bars)

# %% [markdown]
# ## STATES

# %%
# total number of orders from top 10 states...
sales_state = df.groupby(['State'], as_index = False)['Orders'].sum().sort_values(by = 'Orders', ascending = False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x = 'State', y = 'Orders', data = sales_state, palette = 'dark')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17260\2748050046.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'State', y = 'Orders', data = sales_state, palette = 'dark')
# <Axes: xlabel='State', ylabel='Orders'>

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# total amount of sales from top10 states..
sales_state =df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by = 'Amount', ascending = False).head(10)
sns.set(rc={'figure.figsize':(18,8)})
sns.barplot(x = 'State', y='Amount', data=sales_state, palette= 'dark')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17260\3930203042.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'State', y='Amount', data=sales_state, palette= 'dark')
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# Most of the Orders are form the Uttar perdesh, Maharashtra, and karnatka and same time most of the sales are happened from these state respectively..

# %% [markdown]
# # marital status

# %%
ax =  sns.countplot(data = df, x='Marital_Status')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# total amount of sales from top10 states..
sales_state =df.groupby(['Marital_Status','Gender'], as_index=False)['Amount'].sum().sort_values(by = 'Amount', ascending = False).head(10)
sns.set(rc={'figure.figsize':(7,5)})
sns.barplot(x = 'Marital_Status', y='Amount', data=sales_state, hue ='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# Deduction from the above graph is that most of the buyers are married women and they have the most purchasing power..

# %% [markdown]
# # occupation

# %%
ax = sns.countplot(x='Occupation', data = df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
#sns.set(rc={'figure.figsize':(20,5)})
for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17260\1495453674.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %%
sales_state =df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by = 'Amount', ascending = False).head(10)
sns.set(rc={'figure.figsize':(18,8)})
sns.barplot(x = 'Occupation', y='Amount', data=sales_state, palette= 'dark')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17260\2532208261.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Occupation', y='Amount', data=sales_state, palette= 'dark')
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# # Product Category

# %%
ax= sns.countplot(x= 'Product_Category',data= df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17260\3059976626.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %%
sales_state =df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by = 'Amount', ascending = False).head(10)
sns.set(rc={'figure.figsize':(18,8)})
sns.barplot(x = 'Product_Category', y='Amount', data=sales_state, palette= 'dark')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17260\1145792941.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Product_Category', y='Amount', data=sales_state, palette= 'dark')
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
# top 10 most sold products (same thing as above)
fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# From this Analysis we deducted that married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category
